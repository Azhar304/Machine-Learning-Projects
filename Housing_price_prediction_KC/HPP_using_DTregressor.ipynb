# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('./train.csv')

df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])
numeric_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
numeric_df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
numeric_df = numeric_df.drop(columns=['MasVnrArea',], axis=1)
numeric_df['GarageYrBlt'] = numeric_df['GarageYrBlt'].fillna(numeric_df['GarageYrBlt'].mean())
numeric_df['LotFrontage'] = numeric_df['LotFrontage'].fillna(numeric_df['LotFrontage'].mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 numeric_df = numeric_df.drop(columns=['MasVnrArea',], axis=1)
#       2 numeric_df['GarageYrBlt'] = numeric_df['GarageYrBlt'].fillna(numeric_df['GarageYrBlt'].mean())
#       3 numeric_df['LotFrontage'] = numeric_df['LotFrontage'].fillna(numeric_df['LotFrontage'].mean())
#
# File c:\Users\win\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# ...

# %%
X=numeric_df.drop(columns='SalePrice')


from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaled_df = X.copy()

scaled_df[X.columns] = scaler.fit_transform(scaled_df[X.columns])

X_Scaled=scaled_df
Y=numeric_df['SalePrice']
X_Scaled.head()
# Out:
#          Id  MSSubClass   LotFrontage   LotArea  OverallQual  OverallCond  \
# 0 -1.730865    0.073375  1.421085e-14 -0.207142     0.651479    -0.517200
# 1 -1.728492   -0.872563  1.421085e-14 -0.091886    -0.071836     2.179628
# 2 -1.726120    0.073375  1.421085e-14  0.073480     0.651479    -0.517200
# 3 -1.723747    0.309859  1.421085e-14 -0.096897     0.651479    -0.517200
# 4 -1.721374    0.073375  1.421085e-14  0.375148     1.374795    -0.517200
#
#    YearBuilt  YearRemodAdd  BsmtFinSF1  BsmtFinSF2  ...  GarageArea  \
# 0   1.050994      0.878668    0.575425   -0.288653  ...    0.351000
# 1   0.156734     -0.429577    1.171992   -0.288653  ...   -0.060731
# 2   0.984752      0.830215    0.092907   -0.288653  ...    0.631726
# 3  -1.863632     -0.720298   -0.499274   -0.288653  ...    0.790804
# 4   0.951632      0.733308    0.463568   -0.288653  ...    1.698485
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X_Scaled, Y, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

# Hyperparameter grid
param_grid = {
    'max_depth': [5, 10, 15, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [2, 5, 10],
    'max_features': ['sqrt', 'log2'],
    'max_leaf_nodes': [10, 20, 50],
    'ccp_alpha': [0.01, 0.05, 0.1],
}

# Set up GridSearchCV
grid_search = GridSearchCV(DecisionTreeRegressor(random_state=42), param_grid, cv=5, n_jobs=-1)

# Fit model
grid_search.fit(X_train, Y_train)

# Get the best parameters
best_params = grid_search.best_params_
print(best_params)
# Out:
# {'ccp_alpha': 0.01, 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 2}

# %%
model = DecisionTreeRegressor(
    ccp_alpha=0.01,            
    max_depth=10,              
    max_features='sqrt',       
    max_leaf_nodes=50,         
    min_samples_leaf=10,      
    min_samples_split=10      
    
)


model.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.01, max_depth=10, max_features='sqrt',
#                       max_leaf_nodes=50, min_samples_leaf=10,
#                       min_samples_split=10)

# %%
from sklearn.metrics import mean_squared_error

y_train_pred = model.predict(X_train)
train_rmse = mean_squared_error(Y_train, y_train_pred, squared=False)
print(f"Training RMSE is {train_rmse:.2f}")

y_test_pred = model.predict(X_test)
test_rmse = mean_squared_error(Y_test, y_test_pred, squared=False)
print(f"Testing RMSE is {test_rmse:.2f}")
# Out:
# Training RMSE is 32133.35
# Testing RMSE is 38800.69
# c:\Users\win\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\win\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
test_data = pd.read_csv('./test.csv')

numeric_test = test_data.select_dtypes(include=['float64', 'int64'])
numeric_test = numeric_test.drop(columns=['MasVnrArea'], axis=1)
numeric_test['GarageYrBlt'] = numeric_test['GarageYrBlt'].fillna(numeric_test['GarageYrBlt'].mean())
numeric_test['LotFrontage'] = numeric_test['LotFrontage'].fillna(numeric_test['LotFrontage'].mean())

numeric_test.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  BsmtFinSF1  BsmtFinSF2  ...  GarageArea  \
# 0       1961          1961       468.0       144.0  ...       730.0
# 1       1958          1958       923.0         0.0  ...       312.0
# 2       1997          1998       791.0         0.0  ...       482.0
# 3       1998          1998       602.0         0.0  ...       470.0
# 4       1992          1992       263.0         0.0  ...       506.0
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# ...

# %%
scaled_test = numeric_test.copy()
scaled_test[numeric_test.columns] = scaler.transform(scaled_test[numeric_test.columns])
print(scaled_test.isnull().sum())
# Out:
# Id               0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# BsmtFinSF1       1
# BsmtFinSF2       1
# BsmtUnfSF        1
# TotalBsmtSF      1
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     2
# BsmtHalfBath     2
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageYrBlt      0
# GarageCars       1
# GarageArea       1
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# dtype: int64

# %%
import numpy as np

scaled_test.replace({0: np.nan, 'NA': np.nan}, inplace=True)

scaled_test.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageYrBlt      0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# dtype: int64

# %%
test_ids = test_data['Id']

test_predictions = model.predict(scaled_test)

submission = pd.DataFrame({
    'Id': test_ids,
    'SalePrice': test_predictions
})

submission.to_csv('submission3.csv', index=False)

print("Submission file 'submission.csv' created successfully.")
# Out:
# Submission file 'submission.csv' created successfully.
